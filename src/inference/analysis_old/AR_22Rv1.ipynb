# %%
import boto3
import os
import pandas as pd
import glob
import matplotlib.pyplot as plt

from sagemaker import Session

# Initialize a SageMaker session
sagemaker_session = Session()



role = "arn:aws:iam::016114370410:role/tf-binding-sites"



prefix = "inference/output/RB1-VCAP-2024-12-05-01-51-11/"

local_dir = "/data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP"


# Initialize the S3 client
s3 = boto3.client('s3')

# Specify your S3 bucket name
bucket_name = sagemaker_session.default_bucket()


# Function to download files from an S3 bucket
def download_from_s3(bucket_name, prefix, local_dir):
    if not os.path.exists(local_dir):
        os.makedirs(local_dir)

    # List objects within the specified prefix
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

    # Iterate over each object
    for obj in response.get('Contents', []):
        key = obj['Key']
        # Skip if it's a folder
        if key.endswith('/'):
            continue
        local_path = os.path.join(local_dir, os.path.basename(key))
        
        # Download the file
        s3.download_file(bucket_name, key, local_path)
        print(f'Downloaded {key} to {local_path}')

# Bucket name extracted from the S3 URI
bucket_name = "tf-binding-sites"

delete the files in local dir
for file in os.listdir(local_dir):
    os.remove(os.path.join(local_dir, file))
    

# Download the files
download_from_s3(bucket_name, prefix, "/data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP")


# Path to the directory containing JSON files
json_dir = "/data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP"

# Get a list of all JSON files in the directory
json_files = glob.glob(f"{json_dir}/*.jsonl.gz.out")

# Read each JSON file into a DataFrame and store in a list
dataframes = [pd.read_json(file) for file in json_files]

# Concatenate all DataFrames into a single DataFrame
df = pd.concat(dataframes, ignore_index=True)

df
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /data1/home/wjarrard/.config/sagemaker/config.yaml
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_10.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_10.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_100.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_100.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1000.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1000.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1001.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1001.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1002.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1002.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1003.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1003.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1004.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1004.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1005.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1005.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1006.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1006.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1007.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1007.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1008.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1008.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1009.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1009.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_101.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_101.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1010.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1010.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1011.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1011.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1012.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1012.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1013.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1013.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1014.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1014.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1015.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1015.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1016.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1016.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1017.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1017.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1018.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1018.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1019.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1019.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_102.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_102.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1020.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1020.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1021.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1021.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1022.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1022.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1023.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1023.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1024.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1024.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1025.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1025.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1026.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1026.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1027.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1027.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1028.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1028.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1029.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1029.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_103.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_103.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1030.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1030.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1031.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1031.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1032.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1032.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1033.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1033.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1034.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1034.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1035.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1035.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1036.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1036.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1037.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1037.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1038.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1038.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1039.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1039.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_104.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_104.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1040.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1040.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1041.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1041.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1042.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1042.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1043.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1043.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1044.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1044.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1045.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1045.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1046.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1046.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1047.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1047.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1048.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1048.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1049.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1049.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_105.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_105.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1050.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1050.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1051.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1051.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1052.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1052.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1053.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1053.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1054.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1054.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1055.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1055.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1056.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1056.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1057.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1057.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1058.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1058.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1059.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1059.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_106.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_106.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1060.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1060.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1061.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1061.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1062.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1062.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1063.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1063.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1064.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1064.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1065.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1065.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1066.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1066.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1067.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1067.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1068.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1068.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1069.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1069.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_107.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_107.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1070.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1070.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1071.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1071.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1072.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1072.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1073.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1073.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1074.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1074.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1075.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1075.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1076.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1076.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1077.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1077.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1078.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1078.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1079.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1079.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_108.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_108.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1080.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1080.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1081.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1081.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1082.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1082.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1083.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1083.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1084.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1084.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1085.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1085.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1086.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1086.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1087.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1087.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1088.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1088.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1089.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1089.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_109.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_109.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1090.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1090.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1091.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1091.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1092.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1092.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1093.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1093.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1094.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1094.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1095.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1095.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1096.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1096.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1097.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1097.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1098.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1098.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1099.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1099.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_11.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_11.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_110.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_110.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1100.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1100.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1101.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1101.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1102.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1102.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1103.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1103.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1104.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1104.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1105.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1105.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1106.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1106.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1107.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1107.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1108.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1108.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1109.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1109.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_111.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_111.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1110.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1110.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1111.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1111.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1112.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1112.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1113.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1113.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1114.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1114.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1115.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1115.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1116.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1116.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1117.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1117.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1118.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1118.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1119.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1119.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_112.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_112.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1120.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1120.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1121.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1121.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1122.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1122.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1123.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1123.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1124.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1124.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1125.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1125.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1126.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1126.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1127.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1127.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1128.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1128.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1129.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1129.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_113.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_113.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1130.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1130.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1131.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1131.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1132.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1132.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1133.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1133.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1134.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1134.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1135.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1135.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1136.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1136.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1137.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1137.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1138.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1138.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1139.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1139.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_114.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_114.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1140.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1140.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1141.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1141.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1142.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1142.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1143.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1143.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1144.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1144.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1145.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1145.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1146.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1146.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1147.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1147.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1148.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1148.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1149.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1149.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_115.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_115.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1150.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1150.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1151.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1151.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1152.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1152.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1153.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1153.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1154.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1154.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1155.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1155.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1156.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1156.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1157.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1157.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1158.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1158.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1159.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1159.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_116.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_116.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1160.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1160.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1161.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1161.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1162.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1162.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1163.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1163.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1164.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1164.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1165.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1165.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1166.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1166.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1167.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1167.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1168.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1168.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1169.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1169.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_117.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_117.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1170.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1170.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1171.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1171.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1172.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1172.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1173.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1173.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1174.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1174.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1175.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1175.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1176.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1176.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1177.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1177.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1178.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1178.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1179.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1179.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_118.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_118.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1180.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1180.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1181.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1181.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1182.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1182.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1183.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1183.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1184.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1184.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1185.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1185.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1186.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1186.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1187.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1187.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1188.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1188.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1189.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1189.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_119.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_119.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_1190.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_1190.jsonl.gz.out
# ...
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_373.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_373.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_374.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_374.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_375.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_375.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_376.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_376.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_377.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_377.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_378.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_378.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_379.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_379.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_38.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_38.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_380.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_380.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_381.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_381.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_382.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_382.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_383.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_383.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_384.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_384.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_385.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_385.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_386.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_386.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_387.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_387.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_388.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_388.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_389.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_389.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_39.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_39.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_390.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_390.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_391.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_391.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_392.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_392.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_393.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_393.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_394.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_394.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_395.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_395.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_396.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_396.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_397.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_397.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_398.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_398.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_399.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_399.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_4.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_4.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_40.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_40.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_400.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_400.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_401.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_401.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_402.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_402.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_403.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_403.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_404.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_404.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_405.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_405.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_406.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_406.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_407.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_407.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_408.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_408.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_409.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_409.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_41.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_41.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_410.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_410.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_411.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_411.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_412.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_412.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_413.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_413.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_414.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_414.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_415.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_415.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_416.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_416.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_417.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_417.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_418.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_418.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_419.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_419.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_42.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_42.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_420.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_420.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_421.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_421.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_422.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_422.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_423.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_423.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_424.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_424.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_425.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_425.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_426.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_426.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_427.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_427.jsonl.gz.out
# Downloaded inference/output/RB1-VCAP-2024-12-05-01-51-11/dataset_428.jsonl.gz.out to /data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP/dataset_428.jsonl.gz.out
#        chr_name      start        end cell_line  targets  predicted  weights  \
# 0          chr6  151706436  151706662      VCAP        0          0        0
# 1          chr6  151716248  151717168      VCAP        0          0        0
# 2          chr6  151752994  151753248      VCAP        0          0        0
# 3          chr6  151763522  151764687      VCAP        0          1        0
# 4          chr6  151765575  151765869      VCAP        0          0        0
# ...         ...        ...        ...       ...      ...        ...      ...
# 161076     chr4  174089313  174089760      VCAP        0          0        0
# 161077     chr4  174095042  174095209      VCAP        0          0        0
# 161078     chr4  174096728  174097859      VCAP        0          0        0
# 161079     chr4  174100325  174100501      VCAP        0          0        0
# 161080     chr4  174107909  174108663      VCAP        0          0        0
#
#         probabilities                                  linear_512_output  \
# 0            0.033856  [[-1.5430705546999999, -1.5241111517, -1.51646...
# 1            0.231780  [[-0.37438508870000003, -0.48830899600000005, ...
# 2            0.007184  [[-2.1261377335000002, -2.0641069412, -2.01134...
# 3            0.586371  [[0.1793455333, 0.1850048751, 0.1707052737, 0....
# 4            0.417112  [[-0.18515835700000002, -0.28067255020000004, ...
# ...               ...                                                ...
# 161076       0.007718  [[-2.0739345551, -1.9339394569000001, -1.93359...
# 161077       0.015668  [[-1.9991099834, -1.9777239561000002, -1.96056...
# 161078       0.003101  [[-2.7877972126, -2.8495368958, -2.8871102333,...
# 161079       0.028519  [[-1.5870370865, -1.6386932135, -1.620072484, ...
# 161080       0.003916  [[-2.3667676449, -2.2676484585, -2.3259387016,...
#
#                  motifs
# 0       AAACCAATAAGCTTT
# 1       CAGATTTAAACATTC
# 2       TTGAAGAAGCTGTGT
# 3       AAGAAATTCCACTAA
# 4       GCCATCTACAGGGTC
# ...                 ...
# 161076  GCTCTGTCACCCAGG
# 161077  AGGCAGAGGTTGCAG
# 161078  GACCCCCAACCCTCT
# 161079  CAGAACTCAATGCTA
# 161080  AAGAACAAGGACAAC
#
# [161081 rows x 10 columns]

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt


# # Path to the directory containing JSON files
# json_dir = "/data1/datasets_1/human_cistrome/chip-atlas/peak_calls/tfbinding_scripts/tf-binding/data/jsonl_output/RB1-VCAP"

# # Get a list of all JSON files in the directory
# json_files = glob.glob(f"{json_dir}/*.jsonl.gz.out")

# # Read each JSON file into a DataFrame and store in a list
# dataframes = [pd.read_json(file) for file in json_files]

# # Concatenate all DataFrames into a single DataFrame
# df = pd.concat(dataframes, ignore_index=True)

df
# Out:
#        chr_name      start        end cell_line  targets  predicted  weights  \
# 0          chr6  151706436  151706662      VCAP        0          0        0
# 1          chr6  151716248  151717168      VCAP        0          0        0
# 2          chr6  151752994  151753248      VCAP        0          0        0
# 3          chr6  151763522  151764687      VCAP        0          1        0
# 4          chr6  151765575  151765869      VCAP        0          0        0
# ...         ...        ...        ...       ...      ...        ...      ...
# 161076     chr4  174089313  174089760      VCAP        0          0        0
# 161077     chr4  174095042  174095209      VCAP        0          0        0
# 161078     chr4  174096728  174097859      VCAP        0          0        0
# 161079     chr4  174100325  174100501      VCAP        0          0        0
# 161080     chr4  174107909  174108663      VCAP        0          0        0
#
#         probabilities                                  linear_512_output  \
# 0            0.033856  [[-1.5430705546999999, -1.5241111517, -1.51646...
# 1            0.231780  [[-0.37438508870000003, -0.48830899600000005, ...
# 2            0.007184  [[-2.1261377335000002, -2.0641069412, -2.01134...
# 3            0.586371  [[0.1793455333, 0.1850048751, 0.1707052737, 0....
# 4            0.417112  [[-0.18515835700000002, -0.28067255020000004, ...
# ...               ...                                                ...
# 161076       0.007718  [[-2.0739345551, -1.9339394569000001, -1.93359...
# 161077       0.015668  [[-1.9991099834, -1.9777239561000002, -1.96056...
# 161078       0.003101  [[-2.7877972126, -2.8495368958, -2.8871102333,...
# 161079       0.028519  [[-1.5870370865, -1.6386932135, -1.620072484, ...
# 161080       0.003916  [[-2.3667676449, -2.2676484585, -2.3259387016,...
#
#                  motifs
# 0       AAACCAATAAGCTTT
# 1       CAGATTTAAACATTC
# 2       TTGAAGAAGCTGTGT
# 3       AAGAAATTCCACTAA
# 4       GCCATCTACAGGGTC
# ...                 ...
# 161076  GCTCTGTCACCCAGG
# 161077  AGGCAGAGGTTGCAG
# 161078  GACCCCCAACCCTCT
# 161079  CAGAACTCAATGCTA
# 161080  AAGAACAAGGACAAC
#
# [161081 rows x 10 columns]

# %%
# precision and recall
threshold = 0.99
df['tp'] = (df['targets'] == 1) & (df['probabilities'] > threshold)
df['fp'] = (df['targets'] == 0) & (df['probabilities'] > threshold)
df['fn'] = (df['targets'] == 1) & (df['probabilities'] < threshold)
df['tn'] = (df['targets'] == 0) & (df['probabilities'] < threshold)

precision = df['tp'].sum() / (df['tp'].sum() + df['fp'].sum())
recall = df['tp'].sum() / (df['tp'].sum() + df['fn'].sum())

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# f1 score
f1 = 2 * (precision * recall) / (precision + recall)
print(f"F1 score: {f1:.2f}")

# accuracy
accuracy = (df['tp'].sum() + df['tn'].sum()) / len(df)
print(f"Accuracy: {accuracy:.2f}")


print(f"False positives: {df['fp'].sum()}")
print(f"False negatives: {df['fn'].sum()}")
print(f"True positives: {df['tp'].sum()}")
print(f"True negatives: {df['tn'].sum()}")
# Out:
# Precision: 0.30
# Recall: 0.42
# F1 score: 0.35
# Accuracy: 0.99
# False positives: 1073
# False negatives: 656
# True positives: 470
# True negatives: 158882

# %%
# plot false positives, false negatives, true positives, and true negatives
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Plot the number of false positives, false negatives, true positives, and true negatives and give it different colors
df[['fp', 'fn', 'tp', 'tn']].sum().plot(kind='bar', ax=ax, color=['red', 'orange', 'green', 'blue'])

# Add a title and labels
ax.set_title('Model Performance')
ax.set_ylabel('Count')
ax.set_xlabel('Class')

# Display the plot
plt.show()

# %%
# filter out for false positives
df_fp = df[df['fp'] == True]

# get average probability for false positives
avg_prob_fp = df_fp['probabilities'].mean()
print(f"Average probability for false positives: {avg_prob_fp:.2f}")
print(f"Number of false positives: {len(df_fp)}")
# Out:
# Average probability for false positives: 0.90
# Number of false positives: 6946

# %%
# Average probability for true positives
df_tp = df[df['tp'] == True]
avg_prob_tp = df_tp['probabilities'].mean()
print(f"Average probability for true positives: {avg_prob_tp:.2f}")
# Out:
# Average probability for true positives: 0.97

# %%
# Show bar plots with false positives and true positives and thier std


plt.figure(figsize=(10, 6))
plt.bar(['False Positives', 'True Positives'], [avg_prob_fp, avg_prob_tp], yerr=[df_fp['probabilities'].std(), df_tp['probabilities'].std()])
plt.ylabel('Average Probability')
plt.title('Average Probability for False Positives and True Positives')
plt.show()

# %%
# graph with std dev
import matplotlib.pyplot as plt

# Plot the distribution of probabilities for false positives
plt.figure(figsize=(10, 6))
plt.hist(df_fp['probabilities'], bins=20, color='red', alpha=0.7, label='False Positives')
plt.hist(df_tp['probabilities'], bins=20, color='blue', alpha=0.7, label='True Positives')
plt.axvline(avg_prob_fp, color='red', linestyle='--', label='Avg. Probability (FP)')
plt.axvline(avg_prob_tp, color='blue', linestyle='--', label='Avg. Probability (TP)')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.title('Distribution of Predicted Probabilities')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Normalize histograms by setting density=True
plt.figure(figsize=(10, 6))
plt.hist(df_fp['probabilities'], bins=20, color='red', alpha=0.7, label='False Positives', density=True)
plt.hist(df_tp['probabilities'], bins=20, color='blue', alpha=0.7, label='True Positives', density=True)
plt.axvline(avg_prob_fp, color='red', linestyle='--', label='Avg. Probability (FP)')
plt.axvline(avg_prob_tp, color='blue', linestyle='--', label='Avg. Probability (TP)')
plt.xlabel('Probability')
plt.ylabel('Density')
plt.title('Normalized Distribution of Predicted Probabilities')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming df_fp and df_tp are your DataFrames with probabilities and labels
df_fp['label'] = 0  # False positives have label 0
df_tp['label'] = 1  # True positives have label 1

# Combine the DataFrames
df_combined = pd.concat([df_fp, df_tp])

# Sort by probabilities in descending order
df_combined = df_combined.sort_values(by='probabilities', ascending=False)

# Calculate true positive rate (TPR) and false positive rate (FPR) for each threshold
fpr, tpr, thresholds = roc_curve(df_combined['label'], df_combined['probabilities'])

# Calculate Youden's J statistic for each threshold
youden_j = tpr - fpr
optimal_idx = np.argmax(youden_j)
optimal_threshold = thresholds[optimal_idx]

# Plot the ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (area = {auc(fpr, tpr):.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.scatter(fpr[optimal_idx], tpr[optimal_idx], color='red', label=f'Optimal threshold = {optimal_threshold:.2f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

print(f'Optimal threshold based on Youden\'s J statistic: {optimal_threshold:.2f}')
# Out:
# /tmp/ipykernel_165732/184577552.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fp['label'] = 0  # False positives have label 0
# /tmp/ipykernel_165732/184577552.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tp['label'] = 1  # True positives have label 1
# Optimal threshold based on Youden's J statistic: 0.99

# %%
# Apply the optimal threshold to the probabilities
df_combined['predicted'] = (df_combined['probabilities'] >= optimal_threshold).astype(int)
#recalculate tp, fp, tn, fn
df_combined['tp'] = (df_combined['label'] == 1) & (df_combined['predicted'] == 1)
df_combined['fp'] = (df_combined['label'] == 0) & (df_combined['predicted'] == 1)
df_combined['fn'] = (df_combined['label'] == 1) & (df_combined['predicted'] == 0)
df_combined['tn'] = (df_combined['label'] == 0) & (df_combined['predicted'] == 0)

# Calculate precision and recall
precision = df_combined['tp'].sum() / (df_combined['tp'].sum() + df_combined['fp'].sum())
recall = df_combined['tp'].sum() / (df_combined['tp'].sum() + df_combined['fn'].sum())

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# Calculate F1 score
f1 = 2 * (precision * recall) / (precision + recall)
print(f"F1 score: {f1:.2f}")

# Calculate accuracy
accuracy = (df_combined['tp'].sum() + df_combined['tn'].sum()) / len(df_combined)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Precision: 0.89
# Recall: 0.67
# F1 score: 0.77
# Accuracy: 0.70

# %%
# Another pro of colocalization is it narrows the space were looking at, we can just atac and chip for a single tf of interest
# would it be interesting to train a model on the places tp vs fp and see if we can predict the true positives, and still leave one cell line out
Precision: 0.29
Recall: 0.87
F1 score: 0.43
Accuracy: 0.81
# Out:
#   Cell In[20], line 5
#     F1 score: 0.43
#        ^
# SyntaxError: invalid syntax

# %%
# conclusion. not huge difference between greater eequal and greater, theshold might not be where the issue is, maybe its the negatives of the model
