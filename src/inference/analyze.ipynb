# %%
import pandas as pd

# %%
df = pd.read_csv("downloaded_file.tsv", sep='\t')
# Out:
#    chr_name      start        end cell_line  targets  predicted   weights  \
# 0     chr10   42435502   42436016     LNCAP      0.0        0.0  1.634360
# 1      chr1  223519340  223520293     THP-1      0.0        0.0  1.634360
# 2      chr6  106730936  106731954      A549      0.0        1.0  1.634360
# 3      chrX   86101852   86102112      A549      0.0        0.0  1.634360
# 4      chr8     379841     380415     LNCAP      0.0        0.0  1.634360
# 5      chr6  142313368  142314462     LNCAP      1.0        0.0  1.000000
# 6      chr8   33484561   33486103     LNCAP      1.0        1.0  1.000000
# 7      chr5  105952764  105954503     LNCAP      1.0        1.0  2.584963
# 8     chr14   82313586   82314637     LNCAP      1.0        1.0  3.459432
# 9     chr22   45478335   45478715     22Rv1      0.0        0.0  1.634360
# 10    chr19   18506693   18508878      C4-2      1.0        1.0  1.000000
# 11     chr9   64627499   64627992      C4-2      0.0        0.0  1.634360
# ...
