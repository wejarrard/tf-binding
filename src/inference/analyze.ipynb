# %%
import pandas as pd

# %%
df = pd.read_csv("downloaded_file.tsv", sep='\t')
df
# Out:
#    chr_name      start        end cell_line    tf_list             targets  \
# 0     chr10    6275022    6275803     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 1     chr10   32985722   32986323     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 2     chr10   33005278   33006259     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 3     chr11   34371494   34372349     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 4     chr11   43830808   43831458     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 5     chr11   94130598   94131253     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 6     chr12   45415382   45415855     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 7     chr12   54411356   54411772     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 8     chr12   89756222   89757439     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 9     chr12   89768914   89769774     THP-1  ['FOXA1']  tensor([-1.,  1.])
# 10    chr12  107328535  107330132     THP-1  ['FOXA1']  tensor([-1.,  1.])
# ...
