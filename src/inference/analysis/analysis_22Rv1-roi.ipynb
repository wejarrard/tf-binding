# %%
import boto3
import os

from sagemaker import get_execution_role, Session

# Initialize a SageMaker session
sagemaker_session = Session()



role = "arn:aws:iam::016114370410:role/tf-binding-sites"

prefix = "tf-binding-sites/inference/input"
local_dir = "/Users/wejarrard/projects/tf-binding/data/jsonl_output"


# Initialize the S3 client
s3 = boto3.client('s3')

# Specify your S3 bucket name
bucket_name = sagemaker_session.default_bucket()


# Function to download files from an S3 bucket
def download_from_s3(bucket_name, prefix, local_dir):
    if not os.path.exists(local_dir):
        os.makedirs(local_dir)

    # List objects within the specified prefix
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

    # Iterate over each object
    for obj in response.get('Contents', []):
        key = obj['Key']
        # Skip if it's a folder
        if key.endswith('/'):
            continue
        local_path = os.path.join(local_dir, os.path.basename(key))
        
        # Download the file
        s3.download_file(bucket_name, key, local_path)
        print(f'Downloaded {key} to {local_path}')

# Bucket name extracted from the S3 URI
bucket_name = "tf-binding-sites"

# delete the files in local dir
for file in os.listdir(local_dir):
    os.remove(os.path.join(local_dir, file))
    
prefix = "inference/output/22Rv1-PROMOTORS-ENHANCERS"

# Download the files
download_from_s3(bucket_name, prefix, "/Users/wejarrard/projects/tf-binding/data/jsonl_output")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/wejarrard/Library/Application Support/sagemaker/config.yaml
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_1.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_1.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_10.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_10.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_100.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_100.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_101.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_101.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_102.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_102.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_103.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_103.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_104.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_104.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_105.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_105.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_106.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_106.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_107.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_107.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_108.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_108.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_109.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_109.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_11.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_11.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_110.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_110.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_111.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_111.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_112.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_112.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_113.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_113.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_114.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_114.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_115.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_115.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_116.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_116.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_117.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_117.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_118.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_118.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_119.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_119.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_12.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_12.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_120.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_120.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_121.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_121.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_122.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_122.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_123.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_123.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_124.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_124.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_125.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_125.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_126.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_126.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_127.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_127.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_128.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_128.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_129.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_129.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_13.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_13.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_130.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_130.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_14.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_14.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_15.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_15.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_16.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_16.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_17.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_17.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_18.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_18.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_19.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_19.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_2.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_2.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_20.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_20.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_21.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_21.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_22.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_22.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_23.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_23.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_24.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_24.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_25.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_25.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_26.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_26.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_27.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_27.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_28.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_28.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_29.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_29.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_3.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_3.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_30.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_30.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_31.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_31.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_32.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_32.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_33.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_33.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_34.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_34.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_35.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_35.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_36.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_36.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_37.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_37.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_38.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_38.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_39.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_39.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_4.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_4.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_40.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_40.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_41.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_41.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_42.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_42.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_43.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_43.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_44.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_44.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_45.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_45.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_46.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_46.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_47.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_47.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_48.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_48.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_49.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_49.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_5.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_5.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_50.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_50.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_51.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_51.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_52.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_52.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_53.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_53.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_54.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_54.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_55.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_55.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_56.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_56.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_57.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_57.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_58.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_58.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_59.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_59.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_6.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_6.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_60.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_60.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_61.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_61.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_62.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_62.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_63.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_63.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_64.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_64.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_65.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_65.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_66.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_66.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_67.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_67.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_68.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_68.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_69.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_69.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_7.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_7.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_70.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_70.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_71.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_71.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_72.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_72.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_73.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_73.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_74.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_74.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_75.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_75.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_76.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_76.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_77.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_77.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_78.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_78.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_79.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_79.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_8.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_8.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_80.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_80.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_81.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_81.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_82.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_82.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_83.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_83.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_84.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_84.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_85.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_85.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_86.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_86.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_87.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_87.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_88.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_88.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_89.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_89.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_9.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_9.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_90.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_90.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_91.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_91.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_92.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_92.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_93.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_93.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_94.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_94.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_95.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_95.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_96.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_96.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_97.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_97.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_98.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_98.jsonl.gz.out
# Downloaded inference/output/22Rv1-PROMOTORS-ENHANCERS/dataset_99.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_99.jsonl.gz.out

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt


# Path to the directory containing JSON files
json_dir = "/Users/wejarrard/projects/tf-binding/data/jsonl_output"

# Get a list of all JSON files in the directory
json_files = glob.glob(f"{json_dir}/*.jsonl.gz.out")

# Read each JSON file into a DataFrame and store in a list
dataframes = [pd.read_json(file) for file in json_files]

# Concatenate all DataFrames into a single DataFrame
df = pd.concat(dataframes, ignore_index=True)

df

# # precision and recall
df['tp'] = (df['targets'] == 1) & (df['predicted'] == 1)
df['fp'] = (df['targets'] == 0) & (df['predicted'] == 1)
df['fn'] = (df['targets'] == 1) & (df['predicted'] == 0)
df['tn'] = (df['targets'] == 0) & (df['predicted'] == 0)

precision = df['tp'].sum() / (df['tp'].sum() + df['fp'].sum())
recall = df['tp'].sum() / (df['tp'].sum() + df['fn'].sum())

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# f1 score
f1 = 2 * (precision * recall) / (precision + recall)
print(f"F1 score: {f1:.2f}")

# accuracy
accuracy = (df['tp'].sum() + df['tn'].sum()) / len(df)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Precision: 0.36
# Recall: 0.87
# F1 score: 0.51
# Accuracy: 0.88

# %%
print(f"False positives: {df['fp'].sum()}")
print(f"False negatives: {df['fn'].sum()}")
print(f"True positives: {df['tp'].sum()}")
print(f"True negatives: {df['tn'].sum()}")

# plot false positives, false negatives, true positives, and true negatives
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Plot the number of false positives, false negatives, true positives, and true negatives and give it different colors
df[['fp', 'fn', 'tp', 'tn']].sum().plot(kind='bar', ax=ax, color=['red', 'orange', 'green', 'blue'])

# Add a title and labels
ax.set_title('Model Performance')
ax.set_ylabel('Count')
ax.set_xlabel('Class')

# Display the plot
plt.show()
# Out:
# False positives: 8696
# False negatives: 777
# True positives: 4981
# True negatives: 66690

# %%
# filter out for false positives
df_fp = df[df['fp'] == True]

# get average probability for false positives
avg_prob_fp = df_fp['probabilities'].mean()
print(f"Average probability for false positives: {avg_prob_fp:.2f}")
print(f"Number of false positives: {len(df_fp)}")
# Out:
# Average probability for false positives: 0.81
# Number of false positives: 8696

# %%
# Average probability for true positives
df_tp = df[df['tp'] == True]
avg_prob_tp = df_tp['probabilities'].mean()
print(f"Average probability for true positives: {avg_prob_tp:.2f}")
# Out:
# Average probability for true positives: 0.93

# %%
# Show bar plots with false positives and true positives and thier std


plt.figure(figsize=(10, 6))
plt.bar(['False Positives', 'True Positives'], [avg_prob_fp, avg_prob_tp], yerr=[df_fp['probabilities'].std(), df_tp['probabilities'].std()])
plt.ylabel('Average Probability')
plt.title('Average Probability for False Positives and True Positives')
plt.show()

# %%
# graph with std dev
import matplotlib.pyplot as plt

# Plot the distribution of probabilities for false positives
plt.figure(figsize=(10, 6))
plt.hist(df_fp['probabilities'], bins=20, color='red', alpha=0.7, label='False Positives')
plt.hist(df_tp['probabilities'], bins=20, color='blue', alpha=0.7, label='True Positives')
plt.axvline(avg_prob_fp, color='red', linestyle='--', label='Avg. Probability (FP)')
plt.axvline(avg_prob_tp, color='blue', linestyle='--', label='Avg. Probability (TP)')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.title('Distribution of Predicted Probabilities')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Normalize histograms by setting density=True
plt.figure(figsize=(10, 6))
plt.hist(df_fp['probabilities'], bins=20, color='red', alpha=0.7, label='False Positives', density=True)
plt.hist(df_tp['probabilities'], bins=20, color='blue', alpha=0.7, label='True Positives', density=True)
plt.axvline(avg_prob_fp, color='red', linestyle='--', label='Avg. Probability (FP)')
plt.axvline(avg_prob_tp, color='blue', linestyle='--', label='Avg. Probability (TP)')
plt.xlabel('Probability')
plt.ylabel('Density')
plt.title('Normalized Distribution of Predicted Probabilities')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming df_fp and df_tp are your DataFrames with probabilities and labels
df_fp['label'] = 0  # False positives have label 0
df_tp['label'] = 1  # True positives have label 1

# Combine the DataFrames
df_combined = pd.concat([df_fp, df_tp])

# Sort by probabilities in descending order
df_combined = df_combined.sort_values(by='probabilities', ascending=False)

# Calculate true positive rate (TPR) and false positive rate (FPR) for each threshold
fpr, tpr, thresholds = roc_curve(df_combined['label'], df_combined['probabilities'])

# Calculate Youden's J statistic for each threshold
youden_j = tpr - fpr
optimal_idx = np.argmax(youden_j)
optimal_threshold = thresholds[optimal_idx]

# Plot the ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (area = {auc(fpr, tpr):.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.scatter(fpr[optimal_idx], tpr[optimal_idx], color='red', label=f'Optimal threshold = {optimal_threshold:.2f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

print(f'Optimal threshold based on Youden\'s J statistic: {optimal_threshold:.2f}')
# Out:
# /var/folders/0m/90sjqm9d78l50t2x2lmdrztm0000gn/T/ipykernel_33769/184577552.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fp['label'] = 0  # False positives have label 0
# /var/folders/0m/90sjqm9d78l50t2x2lmdrztm0000gn/T/ipykernel_33769/184577552.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tp['label'] = 1  # True positives have label 1
# Optimal threshold based on Youden's J statistic: 0.93

# %%
# Apply the optimal threshold to the probabilities
df_combined['predicted'] = (df_combined['probabilities'] >= optimal_threshold).astype(int)
#recalculate tp, fp, tn, fn
df_combined['tp'] = (df_combined['label'] == 1) & (df_combined['predicted'] == 1)
df_combined['fp'] = (df_combined['label'] == 0) & (df_combined['predicted'] == 1)
df_combined['fn'] = (df_combined['label'] == 1) & (df_combined['predicted'] == 0)
df_combined['tn'] = (df_combined['label'] == 0) & (df_combined['predicted'] == 0)

# Calculate precision and recall
precision = df_combined['tp'].sum() / (df_combined['tp'].sum() + df_combined['fp'].sum())
recall = df_combined['tp'].sum() / (df_combined['tp'].sum() + df_combined['fn'].sum())

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# Calculate F1 score
f1 = 2 * (precision * recall) / (precision + recall)
print(f"F1 score: {f1:.2f}")

# Calculate accuracy
accuracy = (df_combined['tp'].sum() + df_combined['tn'].sum()) / len(df_combined)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Precision: 0.57
# Recall: 0.72
# F1 score: 0.64
# Accuracy: 0.70

# %%
# Another pro of colocalization is it narrows the space were looking at, we can just atac and chip for a single tf of interest
# would it be interesting to train a model on the places tp vs fp and see if we can predict the true positives, and still leave one cell line out
