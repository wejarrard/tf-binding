# %%
import boto3
import os

from sagemaker import get_execution_role, Session

# Initialize a SageMaker session
sagemaker_session = Session()

role = "arn:aws:iam::016114370410:role/tf-binding-sites"

prefix = "tf-binding-sites/inference/input"
local_dir = "/Users/wejarrard/projects/tf-binding/data/jsonl_output"

# Initialize the S3 client
s3 = boto3.client('s3')

# Specify your S3 bucket name
bucket_name = sagemaker_session.default_bucket()


# Function to download files from an S3 bucket
def download_from_s3(bucket_name, prefix, local_dir):
    if not os.path.exists(local_dir):
        os.makedirs(local_dir)

    # List objects within the specified prefix
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

    # Iterate over each object
    for obj in response.get('Contents', []):
        key = obj['Key']
        # Skip if it's a folder
        if key.endswith('/'):
            continue
        local_path = os.path.join(local_dir, os.path.basename(key))
        
        # Download the file
        s3.download_file(bucket_name, key, local_path)
        print(f'Downloaded {key} to {local_path}')

# Bucket name extracted from the S3 URI
bucket_name = "tf-binding-sites"

prefix = "inference/output/PC-3-PROMOTORS-ENHANCERS"

# delete the files in local dir
for file in os.listdir(local_dir):
    os.remove(os.path.join(local_dir, file))

# Download the files
download_from_s3(bucket_name, prefix, "/Users/wejarrard/projects/tf-binding/data/jsonl_output")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/wejarrard/Library/Application Support/sagemaker/config.yaml
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_1.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_1.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_10.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_10.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_11.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_11.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_12.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_12.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_13.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_13.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_14.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_14.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_15.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_15.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_16.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_16.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_17.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_17.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_18.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_18.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_19.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_19.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_2.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_2.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_20.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_20.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_21.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_21.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_22.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_22.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_23.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_23.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_24.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_24.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_25.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_25.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_26.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_26.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_27.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_27.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_28.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_28.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_29.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_29.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_3.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_3.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_30.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_30.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_31.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_31.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_32.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_32.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_33.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_33.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_34.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_34.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_35.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_35.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_36.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_36.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_37.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_37.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_38.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_38.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_39.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_39.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_4.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_4.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_40.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_40.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_41.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_41.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_42.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_42.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_43.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_43.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_44.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_44.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_45.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_45.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_46.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_46.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_47.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_47.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_48.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_48.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_49.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_49.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_5.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_5.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_50.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_50.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_51.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_51.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_52.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_52.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_53.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_53.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_54.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_54.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_55.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_55.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_56.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_56.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_57.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_57.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_58.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_58.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_59.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_59.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_6.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_6.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_60.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_60.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_61.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_61.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_7.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_7.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_8.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_8.jsonl.gz.out
# Downloaded inference/output/PC-3-PROMOTORS-ENHANCERS/dataset_9.jsonl.gz.out to /Users/wejarrard/projects/tf-binding/data/jsonl_output/dataset_9.jsonl.gz.out

# %%
import pandas as pd
import glob

# Path to the directory containing JSON files
json_dir = "/Users/wejarrard/projects/tf-binding/data/jsonl_output"

# Get a list of all JSON files in the directory
json_files = glob.glob(f"{json_dir}/*.jsonl.gz.out")

# Read each JSON file into a DataFrame and store in a list
dataframes = [pd.read_json(file) for file in json_files]

# Concatenate all DataFrames into a single DataFrame
df = pd.concat(dataframes, ignore_index=True)

df

# # # precision and recall
df['tp'] = (df['targets'] == 1) & (df['predicted'] == 1)
df['fp'] = (df['targets'] == 0) & (df['predicted'] == 1)
df['fn'] = (df['targets'] == 1) & (df['predicted'] == 0)
df['tn'] = (df['targets'] == 0) & (df['predicted'] == 0)

precision = df['tp'].sum() / (df['tp'].sum() + df['fp'].sum())
recall = df['tp'].sum() / (df['tp'].sum() + df['fn'].sum())

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# # f1 score
f1 = 2 * (precision * recall) / (precision + recall)
print(f"F1 score: {f1:.2f}")

# accuracy
accuracy = (df['tp'].sum() + df['tn'].sum()) / len(df)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Precision: 0.00
# Recall: nan
# F1 score: nan
# Accuracy: 0.99
# /var/folders/0m/90sjqm9d78l50t2x2lmdrztm0000gn/T/ipykernel_8755/2071561556.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   recall = df['tp'].sum() / (df['tp'].sum() + df['fn'].sum())

# %%
print(f"False positives: {df['fp'].sum()}")
print(f"False negatives: {df['fn'].sum()}")
print(f"True positives: {df['tp'].sum()}")
print(f"True negatives: {df['tn'].sum()}")
# Out:
# False positives: 283
# False negatives: 0
# True positives: 0
# True negatives: 53226

# %%
# Graph number of true positives, false positives, true negatives, and false negatives
import matplotlib.pyplot as plt

# Group by the 'targets' and 'predicted' columns
grouped = df.groupby(['targets', 'predicted']).size().unstack()

# Plot the grouped data
grouped.plot(kind='bar', stacked=True)
plt.xlabel('Targets')
plt.ylabel('Count')
plt.title('Predicted vs. Actual')
plt.legend(title='Predicted')

plt.show()

# Plot the ROC curve

# %%
# filter out for false positives
df_fp = df[df['fp'] == True]

# get average probability for false positives
avg_prob_fp = df_fp['probabilities'].mean()
print(f"Average probability for false positives: {avg_prob_fp:.2f}")
print(f"Number of false positives: {len(df_fp)}")
# Out:
# Average probability for false positives: 0.74
# Number of false positives: 283

# %%
# Average probability for true positives
df_tp = df[df['tp'] == True]
avg_prob_tp = df_tp['probabilities'].mean()
print(f"Average probability for true positives: {avg_prob_tp:.2f}")
# Out:
# Average probability for true positives: nan

# %%
import matplotlib.pyplot as plt

# Show bar plots with false positives and true positives and thier std
plt.figure(figsize=(10, 6))
plt.bar(['False Positives', 'True Positives'], [avg_prob_fp, avg_prob_tp], yerr=[df_fp['probabilities'].std(), df_tp['probabilities'].std()])
plt.ylabel('Average Probability')
plt.title('Average Probability for False Positives and True Positives')
plt.show()

# %%
# graph with std dev

# Plot the distribution of probabilities for false positives
plt.figure(figsize=(10, 6))
plt.hist(df_fp['probabilities'], bins=20, color='red', alpha=0.7, label='False Positives')
plt.hist(df_tp['probabilities'], bins=20, color='blue', alpha=0.7, label='True Positives')
plt.axvline(avg_prob_fp, color='red', linestyle='--', label='Avg. Probability (FP)')
plt.axvline(avg_prob_tp, color='blue', linestyle='--', label='Avg. Probability (TP)')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.title('Distribution of Predicted Probabilities')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Normalize histograms by setting density=True
plt.figure(figsize=(10, 6))
plt.hist(df_fp['probabilities'], bins=20, color='red', alpha=0.7, label='False Positives', density=True)
plt.hist(df_tp['probabilities'], bins=20, color='blue', alpha=0.7, label='True Positives', density=True)
plt.axvline(avg_prob_fp, color='red', linestyle='--', label='Avg. Probability (FP)')
plt.axvline(avg_prob_tp, color='blue', linestyle='--', label='Avg. Probability (TP)')
plt.xlabel('Probability')
plt.ylabel('Density')
plt.title('Normalized Distribution of Predicted Probabilities')
plt.legend()
plt.show()
# Out:
# /Users/wejarrard/projects/tf-binding/.venv/lib/python3.10/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
